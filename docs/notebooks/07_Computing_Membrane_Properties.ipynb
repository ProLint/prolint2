# %%
from prolint2 import Universe
from prolint2.sampledata import GIRKDataSample
GIRK = GIRKDataSample()
u = Universe(GIRK.coordinates, GIRK.trajectory)

# %% [markdown]
# #### Thickness

# %%
import numpy as np
np.unique(u.database.residues.resnames)
# Out:
# array(['CHOL', 'POPE', 'POPS'], dtype=object)

# %%
from prolint2.plotting import MosaicsGridData

MGD = MosaicsGridData('delta_z.dat')
MGD.create_plot(frame=20, cmap='Spectral')
# Out:
# Fontconfig warning: ignoring UTF-8: not a valid region tag

# %%
MGD.generate_script(MosaicsGridData, 'plot_mosaics_grid_data.py')
